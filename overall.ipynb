# %%
import pandas as pd

# %%
album_metadata = pd.read_csv("data/album_metadata.csv")
artist_metadata = pd.read_csv("data/artists_metadata.csv")
playlist_metadata = pd.read_csv("data/playlist_metadata.csv")
rating_metadata = pd.read_csv("data/rating_metadata.csv")
track_metadata = pd.read_csv("data/track_metadata.csv")

# %%
track_metadata
# Out:
#                          id  duration_ms  popularity  track_number  explicit  \
# 0    0WP8Hwr2s3Fhwu14ehgUUT       261500          46             1     False
# 1    1rNYuv63emsYt4Jjv8RlgJ       240008          61             4     False
# 2    5CyYkeczaCPesQQMICCbmp       226703          41             1     False
# 3    3T03rPwlL8NVk1yIaxeD8U       156467          76             4     False
# 4    3ZPBZH2k9p306C1bu7bkhC       208000          69            17     False
# ..                      ...          ...         ...           ...       ...
# 142  2gMXnyrvIjhVBUZwvLZDMP       215106          83            13     False
# 143  4o3XxiQ9BljY4OU38zanC0       193976          69             1     False
# 144  3hRV0jL3vUpRrcy398teAU       208211          83            14     False
# 145  3JE04xcSOB8zuUzzazuaDj       195401          66             1     False
# 146  0Jlcvv8IykzHaSmj49uNW8       210251          76             1      True
#
#                          name  \
# ...

# %%
rating_metadata = rating_metadata[["track_id", "Rating (1-10)"]]

# %%
rating_metadata = rating_metadata.rename(columns={"track_id": "id"})

# %%
overall_data = track_metadata.merge(rating_metadata, on="id")

# %%
overall_data
# Out:
#                          id  duration_ms  popularity  track_number  explicit  \
# 0    0WP8Hwr2s3Fhwu14ehgUUT       261500          46             1     False
# 1    1rNYuv63emsYt4Jjv8RlgJ       240008          61             4     False
# 2    5CyYkeczaCPesQQMICCbmp       226703          41             1     False
# 3    3T03rPwlL8NVk1yIaxeD8U       156467          76             4     False
# 4    3ZPBZH2k9p306C1bu7bkhC       208000          69            17     False
# ..                      ...          ...         ...           ...       ...
# 142  2gMXnyrvIjhVBUZwvLZDMP       215106          83            13     False
# 143  4o3XxiQ9BljY4OU38zanC0       193976          69             1     False
# 144  3hRV0jL3vUpRrcy398teAU       208211          83            14     False
# 145  3JE04xcSOB8zuUzzazuaDj       195401          66             1     False
# 146  0Jlcvv8IykzHaSmj49uNW8       210251          76             1      True
#
#                          name  \
# ...
